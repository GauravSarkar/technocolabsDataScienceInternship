# %%
import pandas as pd
df =pd.read_csv("unrate.csv")
df['DATE'] = pd.to_datetime(df['DATE'])
x = df.head(12)["DATE"]
y = df.head(12)["VALUE"]
import matplotlib.pyplot as plt

plt.plot(x, y)
plt.xlabel("Month")
plt.ylabel("Unemployment Rate")
plt.title("Monthly Unemployment Trends, 1948")
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
for i in range(2):
    ax = fig.add_subplot(2,1,i+1)
    start_index = i*12
    end_index = (i+1)*12
    subset = df[start_index:end_index]
    ax.plot(subset['DATE'], subset['VALUE'])
plt.show( )

# %%
fig = plt.figure(figsize=(12,12))
for i in range(5):
    ax = fig.add_subplot(5,1,i+1)
    start_index = i*12
    end_index = (i+1)*12
    subset = df[start_index:end_index]
    ax.plot(subset['DATE'], subset['VALUE'])
plt.show( )

# %%
df['MONTH'] = df['DATE'].dt.month

# %%
df.head(50)
# Out:
#          DATE  VALUE  MONTH
# 0  1948-01-01    3.4      1
# 1  1948-02-01    3.8      2
# 2  1948-03-01    4.0      3
# 3  1948-04-01    3.9      4
# 4  1948-05-01    3.5      5
# 5  1948-06-01    3.6      6
# 6  1948-07-01    3.6      7
# 7  1948-08-01    3.9      8
# 8  1948-09-01    3.8      9
# 9  1948-10-01    3.7     10
# 10 1948-11-01    3.8     11
# 11 1948-12-01    4.0     12
# 12 1949-01-01    4.3      1
# 13 1949-02-01    4.7      2
# 14 1949-03-01    5.0      3
# 15 1949-04-01    5.3      4
# 16 1949-05-01    6.1      5
# 17 1949-06-01    6.2      6
# 18 1949-07-01    6.7      7
# 19 1949-08-01    6.8      8
# 20 1949-09-01    6.6      9
# 21 1949-10-01    7.9     10
# 22 1949-11-01    6.4     11
# 23 1949-12-01    6.6     12
# 24 1950-01-01    6.5      1
# 25 1950-02-01    6.4      2
# 26 1950-03-01    6.3      3
# 27 1950-04-01    5.8      4
# 28 1950-05-01    5.5      5
# 29 1950-06-01    5.4      6
# 30 1950-07-01    5.0      7
# 31 1950-08-01    4.5      8
# 32 1950-09-01    4.4      9
# 33 1950-10-01    4.2     10
# 34 1950-11-01    4.2     11
# 35 1950-12-01    4.3     12
# 36 1951-01-01    3.7      1
# 37 1951-02-01    3.4      2
# 38 1951-03-01    3.4      3
# 39 1951-04-01    3.1      4
# 40 1951-05-01    3.0      5
# 41 1951-06-01    3.2      6
# 42 1951-07-01    3.1      7
# 43 1951-08-01    3.1      8
# 44 1951-09-01    3.3      9
# 45 1951-10-01    3.5     10
# 46 1951-11-01    3.5     11
# 47 1951-12-01    3.1     12
# 48 1952-01-01    3.2      1
# 49 1952-02-01    3.1      2

# %%
fig = plt.figure(figsize=(6,3))
plt.plot(df[0:12]['MONTH'], df[0:12]['VALUE'])
plt.plot(df[12:24]['MONTH'], df[12:24]['VALUE'])

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(df[0:12]['MONTH'], df[0:12]['VALUE'],c='red', label='1948')
plt.plot(df[12:24]['MONTH'], df[12:24]['VALUE'],c='blue', label='1949')
plt.plot(df[24:36]['MONTH'], df[24:36]['VALUE'],c='green', label='1950')
plt.plot(df[36:48]['MONTH'], df[36:48]['VALUE'],c='orange', label='1951')
plt.plot(df[48:60]['MONTH'], df[48:60]['VALUE'],c='black', label='1952')
plt.legend(loc='upper left')
plt.title("Monthly Unemployment Trends, 1948-1952")
plt.xlabel("Month,Integer")
plt.ylabel("Unemployment Rate,Percent")
plt.title("Monthly Unemployment Trends, 1948")
plt.show()
