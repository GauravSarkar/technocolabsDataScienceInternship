# %%
import pandas as pd

# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 0: invalid start byte
df = pd.read_csv("Minimum Wage Data.csv", encoding="latin")

# %%
df.to_csv("minwage.csv", encoding="utf-8")

# %%
df = pd.read_csv("minwage.csv")

# %%
df.head(50)
# Out:
#     Unnamed: 0  Year                 State           Table_Data Footnote  \
# 0            0  1968               Alabama                  ...      NaN
# 1            1  1968                Alaska                 2.10      NaN
# 2            2  1968               Arizona  18.72 - 26.40/wk(b)      (b)
# 3            3  1968              Arkansas          1.25/day(b)      (b)
# 4            4  1968            California              1.65(b)      (b)
# 5            5  1968              Colorado       1.00 - 1.25(b)      (b)
# 6            6  1968           Connecticut                 1.40      NaN
# 7            7  1968              Delaware                 1.25      NaN
# 8            8  1968  District of Columbia          1.25 - 1.40      NaN
# 9            9  1968        Federal (FLSA)        $1.15 & $1.60      NaN
# 10          10  1968               Florida                  ...      NaN
# 11          11  1968               Georgia                  ...      NaN
# 12          12  1968                  Guam                 1.25      NaN
# 13          13  1968                Hawaii                 1.25      NaN
# 14          14  1968                 Idaho                 1.15      NaN
# 15          15  1968              Illinois                  ...      NaN
# 16          16  1968               Indiana                 1.15      NaN
# 17          17  1968                  Iowa                  ...      NaN
# 18          18  1968                Kansas                  ...      NaN
# 19          19  1968              Kentucky         .65 - .75(b)      (b)
# 20          20  1968             Louisiana                  ...      NaN
# 21          21  1968                 Maine                 1.40      NaN
# 22          22  1968              Maryland          1.00 & 1.15      NaN
# 23          23  1968         Massachusetts                 1.60      NaN
# 24          24  1968              Michigan                 1.25      NaN
# 25          25  1968             Minnesota        .70 - 1.15(b)      (b)
# 26          26  1968           Mississippi                  ...      NaN
# 27          27  1968              Missouri                  ...      NaN
# 28          28  1968               Montana                  ...      NaN
# 29          29  1968              Nebraska                 1.00      NaN
# 30          30  1968                Nevada                 1.25      NaN
# 31          31  1968         New Hampshire                 1.40      NaN
# 32          32  1968            New Jersey                 1.40      NaN
# 33          33  1968            New Mexico          1.15 - 1.40      NaN
# 34          34  1968              New York                 1.60      NaN
# 35          35  1968        North Carolina                 1.00      NaN
# 36          36  1968          North Dakota          1.00 - 1.25      NaN
# 37          37  1968                  Ohio        .75 - 1.25(b)      (b)
# 38          38  1968              Oklahoma                 1.00      NaN
# 39          39  1968                Oregon                 1.25      NaN
# 40          40  1968          Pennsylvania                 1.15      NaN
# 41          41  1968           Puerto Rico           .43 - 1.60      NaN
# 42          42  1968          Rhode Island                 1.40      NaN
# 43          43  1968        South Carolina                  ...      NaN
# 44          44  1968          South Dakota     17.00 - 20.00/wk      NaN
# 45          45  1968             Tennessee                  ...      NaN
# 46          46  1968                 Texas                  ...      NaN
# 47          47  1968   U.S. Virgin Islands                  NaN      NaN
# 48          48  1968                  Utah       1.00 - 1.15(b)      (b)
# 49          49  1968               Vermont                 1.40      NaN
#
#     High.Value  Low.Value  CPI.Average  High.2018  Low.2018
# 0      0.00000    0.00000    34.783333       0.00      0.00
# 1      2.10000    2.10000    34.783333      15.12     15.12
# 2      0.66000    0.46800    34.783333       4.75      3.37
# 3      0.15625    0.15625    34.783333       1.12      1.12
# 4      1.65000    1.65000    34.783333      11.88     11.88
# 5      1.25000    1.00000    34.783333       9.00      7.20
# 6      1.40000    1.40000    34.783333      10.08     10.08
# 7      1.25000    1.25000    34.783333       9.00      9.00
# 8      1.40000    1.25000    34.783333      10.08      9.00
# 9      1.60000    1.15000    34.783333      11.52      8.28
# 10     0.00000    0.00000    34.783333       0.00      0.00
# 11     0.00000    0.00000    34.783333       0.00      0.00
# 12     1.25000    1.25000    34.783333       9.00      9.00
# 13     1.25000    1.25000    34.783333       9.00      9.00
# 14     1.15000    1.15000    34.783333       8.28      8.28
# 15     0.00000    0.00000    34.783333       0.00      0.00
# 16     1.15000    1.15000    34.783333       8.28      8.28
# 17     0.00000    0.00000    34.783333       0.00      0.00
# 18     0.00000    0.00000    34.783333       0.00      0.00
# 19     0.75000    0.65000    34.783333       5.40      4.68
# 20     0.00000    0.00000    34.783333       0.00      0.00
# 21     1.40000    1.40000    34.783333      10.08     10.08
# 22     1.15000    1.00000    34.783333       8.28      7.20
# 23     1.60000    1.60000    34.783333      11.52     11.52
# 24     1.25000    1.25000    34.783333       9.00      9.00
# 25     1.15000    0.70000    34.783333       8.28      5.04
# 26     0.00000    0.00000    34.783333       0.00      0.00
# 27     0.00000    0.00000    34.783333       0.00      0.00
# 28     0.00000    0.00000    34.783333       0.00      0.00
# 29     1.00000    1.00000    34.783333       7.20      7.20
# 30     1.25000    1.25000    34.783333       9.00      9.00
# 31     1.40000    1.40000    34.783333      10.08     10.08
# 32     1.40000    1.40000    34.783333      10.08     10.08
# 33     1.40000    1.15000    34.783333      10.08      8.28
# 34     1.60000    1.60000    34.783333      11.52     11.52
# 35     1.00000    1.00000    34.783333       7.20      7.20
# 36     1.25000    1.00000    34.783333       9.00      7.20
# 37     1.25000    0.75000    34.783333       9.00      5.40
# 38     1.00000    1.00000    34.783333       7.20      7.20
# 39     1.25000    1.25000    34.783333       9.00      9.00
# 40     1.15000    1.15000    34.783333       8.28      8.28
# 41     1.60000    0.43000    34.783333      11.52      3.10
# 42     1.40000    1.40000    34.783333      10.08     10.08
# 43     0.00000    0.00000    34.783333       0.00      0.00
# 44     0.50000    0.42500    34.783333       3.60      3.06
# 45     0.00000    0.00000    34.783333       0.00      0.00
# 46     0.00000    0.00000    34.783333       0.00      0.00
# 47         NaN        NaN    34.783333        NaN       NaN
# 48     1.15000    1.00000    34.783333       8.28      7.20
# 49     1.40000    1.40000    34.783333      10.08     10.08

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State Table_Data Footnote  High.Value  Low.Value  \
# Year
# 1968           0  Alabama        ...      NaN         0.0        0.0
# 1969          55  Alabama        ...      NaN         0.0        0.0
# 1970         110  Alabama        ...      NaN         0.0        0.0
# 1971         165  Alabama        ...      NaN         0.0        0.0
# 1972         220  Alabama        ...      NaN         0.0        0.0
#
#       CPI.Average  High.2018  Low.2018
# Year
# 1968    34.783333        0.0       0.0
# 1969    36.683333        0.0       0.0
# 1970    38.825000        0.0       0.0
# 1971    40.491667        0.0       0.0
# 1972    41.816667        0.0       0.0

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["High.2018"]].rename(columns={"High.2018":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["High.2018"]].rename(columns={"High.2018":name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.12     4.75      1.12       11.88      9.00        10.08
# 1969      0.0   14.33     4.51      1.07       11.26      8.53         9.56
# 1970      0.0   13.54     4.26      7.09       10.64      8.06        10.32
# 1971      0.0   12.99     4.08      6.80       10.20      7.73         9.89
# 1972      0.0   12.57     3.95      7.19        9.88      7.49        11.08
#
#       Delaware  District of Columbia  Federal (FLSA)  ...  Tennessee  Texas  \
# Year                                                  ...
# 1968      9.00                 10.08           11.52  ...        0.0   0.00
# 1969      8.53                  9.56           10.92  ...        0.0   0.00
# 1970      8.06                 12.90           10.32  ...        0.0   0.00
# 1971      7.73                 12.37            9.89  ...        0.0   0.00
# 1972      9.58                 13.47            9.58  ...        0.0   8.38
#
#       U.S. Virgin Islands  Utah  Vermont  Virginia  Washington  West Virginia  \
# Year
# 1968                  NaN  8.28    10.08       0.0       11.52           7.20
# 1969                  NaN  7.85     9.56       0.0       10.92           6.83
# 1970                  NaN  7.42    10.32       0.0       10.32           6.45
# 1971                  NaN  7.11     9.89       0.0        9.89           6.18
# 1972                  NaN  8.08     9.58       0.0        9.58           7.19
#
#       Wisconsin  Wyoming
# Year
# 1968       9.00     8.64
# 1969       8.53     8.19
# 1970       8.38     8.38
# 1971       8.04     8.04
# 1972       8.68     8.98
#
# [5 rows x 55 columns]

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     50.0  50.000000  50.000000  50.000000   50.000000  50.000000
# mean       0.0   9.583800   2.500600   6.781600    8.632800   6.691800
# std        0.0   1.845176   3.530273   1.341223    1.187508   1.495979
# min        0.0   7.380000   0.000000   1.070000    6.420000   4.190000
# 25%        0.0   8.252500   0.000000   6.522500    7.695000   5.260000
# 50%        0.0   8.890000   0.000000   6.920000    8.670000   6.715000
# 75%        0.0  10.492500   4.447500   7.290000    9.307500   8.135000
# max        0.0  15.120000  10.220000   8.680000   11.880000   9.500000
#
#        Connecticut   Delaware  District of Columbia  Federal (FLSA)  ...  \
# count    50.000000  50.000000              50.00000        50.00000  ...
# mean      8.848400   7.498800               9.72800         8.00000  ...
# std       1.036049   1.265436               1.46308         1.22897  ...
# min       6.820000   4.410000               6.98000         6.22000  ...
# 25%       7.865000   7.015000               8.70750         7.17250  ...
# 50%       9.075000   7.845000               9.44000         7.65500  ...
# 75%       9.477500   8.327500              10.44000         8.62250  ...
# max      11.080000   9.580000              13.47000        11.52000  ...
#
#        Tennessee      Texas  U.S. Virgin Islands       Utah    Vermont  \
# count       50.0  50.000000            39.000000  50.000000  50.000000
# mean         0.0   5.541200             7.547692   7.165600   8.657400
# std          0.0   2.202229             0.926903   0.716329   0.984647
# min          0.0   0.000000             5.780000   5.270000   6.800000
# 25%          0.0   4.762500             7.040000   6.785000   7.800000
# 50%          0.0   6.070000             7.560000   7.230000   8.885000
# 75%          0.0   7.105000             8.065000   7.655000   9.372500
# max          0.0   8.380000            10.010000   8.450000  10.320000
#
#         Virginia  Washington  West Virginia  Wisconsin    Wyoming
# count  50.000000   50.000000      50.000000  50.000000  50.000000
# mean    5.897400    8.326600       7.166400   7.694200   5.149200
# std     2.726151    1.881944       0.793673   0.762675   1.998928
# min     0.000000    4.410000       5.580000   6.420000   2.260000
# 25%     5.892500    7.227500       6.630000   7.107500   3.270000
# 50%     6.855000    9.205000       7.075000   7.580000   5.445000
# 75%     7.620000    9.777500       7.612500   8.145000   6.607500
# max     8.800000   11.520000       9.130000   9.660000   8.980000
#
# [8 rows x 55 columns]

# %%
act_min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.112159 -0.377934    0.717653  0.201963
# Arizona         NaN  0.112159  1.000000  0.018024    0.556224  0.774318
# Arkansas        NaN -0.377934  0.018024  1.000000   -0.234367 -0.042403
# California      NaN  0.717653  0.556224 -0.234367    1.000000  0.678058
#
#             Connecticut  Delaware  District of Columbia  Federal (FLSA)  ...  \
# Alabama             NaN       NaN                   NaN             NaN  ...
# Alaska         0.699115  0.258997              0.673489        0.901026  ...
# Arizona        0.486908  0.464161              0.245736        0.068183  ...
# Arkansas       0.066554  0.016125              0.143713       -0.335254  ...
# California     0.858218  0.479197              0.457740        0.617172  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# Alabama           NaN       NaN                  NaN       NaN       NaN
# Alaska            NaN -0.522472             0.518713  0.387844  0.663558
# Arizona           NaN  0.310952             0.067718  0.378509  0.548177
# Arkansas          NaN  0.503242             0.166108  0.012765  0.087429
# California        NaN -0.239533             0.165680  0.605122  0.877922
#
#             Virginia  Washington  West Virginia  Wisconsin   Wyoming
# Alabama          NaN         NaN            NaN        NaN       NaN
# Alaska     -0.601640    0.423212       0.044814   0.702570  0.727932
# Arizona    -0.068646    0.606844       0.536635   0.164838  0.422853
# Arkansas    0.582192   -0.061071       0.420819   0.000470 -0.250592
# California -0.326364    0.744626       0.371765   0.584067  0.722617
#
# [5 rows x 55 columns]

# %%
issue_df = df[df['Low.2018']==0]

issue_df
# Out:
#       Unnamed: 0  Year           State Table_Data Footnote  High.Value  \
# 0              0  1968         Alabama        ...      NaN         0.0
# 10            10  1968         Florida        ...      NaN         0.0
# 11            11  1968         Georgia        ...      NaN         0.0
# 15            15  1968        Illinois        ...      NaN         0.0
# 17            17  1968            Iowa        ...      NaN         0.0
# ...          ...   ...             ...        ...      ...         ...
# 2695        2695  2017         Alabama        ...      NaN         0.0
# 2715        2715  2017       Louisiana        ...      NaN         0.0
# 2721        2721  2017     Mississippi        ...      NaN         0.0
# 2738        2738  2017  South Carolina        ...      NaN         0.0
# 2740        2740  2017       Tennessee        ...      NaN         0.0
#
#       Low.Value  CPI.Average  High.2018  Low.2018
# 0           0.0    34.783333        0.0       0.0
# 10          0.0    34.783333        0.0       0.0
# 11          0.0    34.783333        0.0       0.0
# 15          0.0    34.783333        0.0       0.0
# 17          0.0    34.783333        0.0       0.0
# ...         ...          ...        ...       ...
# 2695        0.0   245.119583        0.0       0.0
# 2715        0.0   245.119583        0.0       0.0
# 2721        0.0   245.119583        0.0       0.0
# 2738        0.0   245.119583        0.0       0.0
# 2740        0.0   245.119583        0.0       0.0
#
# [400 rows x 10 columns]

# %%
issue_df['State'].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'Virginia', 'Arizona'],
#       dtype=object)

# %%
import numpy as np

# axis 1 == columns. 0,default, is for rows
act_min_wage.replace(0, np.NaN).dropna(axis=1).corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653  0.201963     0.699115  0.258997
# Arkansas    -0.377934  1.000000   -0.234367 -0.042403     0.066554  0.016125
# California   0.717653 -0.234367    1.000000  0.678058     0.858218  0.479197
# Colorado     0.201963 -0.042403    0.678058  1.000000     0.572078  0.727864
# Connecticut  0.699115  0.066554    0.858218  0.572078     1.000000  0.560850
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.673489        0.901026  0.787915  0.672620  ...
# Arkansas                 0.143713       -0.335254  0.039593  0.204801  ...
# California               0.457740        0.617172  0.492052  0.519241  ...
# Colorado                 0.239137        0.127869  0.079973  0.292030  ...
# Connecticut              0.669779        0.563760  0.652939  0.659447  ...
#
#              Pennsylvania  Puerto Rico  Rhode Island  South Dakota      Utah  \
# Alaska           0.610814     0.838675      0.652353     -0.294266  0.387844
# Arkansas         0.159923    -0.334207      0.003498      0.765024  0.012765
# California       0.429061     0.487280      0.780916      0.002955  0.605122
# Colorado         0.021233     0.095910      0.661957      0.266817  0.519295
# Connecticut      0.561204     0.479519      0.822384      0.153930  0.504585
#
#               Vermont  Washington  West Virginia  Wisconsin   Wyoming
# Alaska       0.663558    0.423212       0.044814   0.702570  0.727932
# Arkansas     0.087429   -0.061071       0.420819   0.000470 -0.250592
# California   0.877922    0.744626       0.371765   0.584067  0.722617
# Colorado     0.610147    0.750629       0.481995   0.174696  0.414536
# Connecticut  0.908816    0.721482       0.429235   0.610449  0.823097
#
# [5 rows x 39 columns]

# %%
min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()

# %%
for problem in issue_df['State'].unique():
    if problem in min_wage_corr.columns:
        print("Missing something here....")

# %%
grouped_issues = issue_df.groupby("State")

grouped_issues.get_group("Alabama").head(3)
# Out:
#      Unnamed: 0  Year    State Table_Data Footnote  High.Value  Low.Value  \
# 0             0  1968  Alabama        ...      NaN         0.0        0.0
# 55           55  1969  Alabama        ...      NaN         0.0        0.0
# 110         110  1970  Alabama        ...      NaN         0.0        0.0
#
#      CPI.Average  High.2018  Low.2018
# 0      34.783333        0.0       0.0
# 55     36.683333        0.0       0.0
# 110    38.825000        0.0       0.0

# %%
grouped_issues.get_group("Alabama")['Low.2018'].sum()
# Out:
# 0.0

# %%
for state, data in grouped_issues:
    if data['Low.2018'].sum() != 0.0:
        print("Some data found for", state)
